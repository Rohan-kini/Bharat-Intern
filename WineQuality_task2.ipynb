# %% [markdown]
# # Red Wine Quality Prediction

# %% [markdown]
# # Importing the Dataset:

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Adarsh Gupta\OneDrive\Desktop\Bharat intern\winequality-red_n.csv") #reading the data file
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape #The Total number of data (same as df)
# Out:
# (1599, 12)

# %%
df.columns #to see the columns names
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.head() #to see 5 first row of dataset
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# # Checking for NULL values if any in the data frame
#
# np.nan, None, NaN and others..

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # Check the datatypes of the columns

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# We can observe that the "Total Charges" column has continuous data but it is an object type. Let us handle this column

# %%
df['quality'].unique() # we see there is object data in the int data
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
#We are creating a Classification model , so we will try to make the target variable into binary classification

#df['quality'] = ((df['quality']>5).astype(int)) #tried bool control function to seperate did not work as intended so using other functions 
df['quality'] = np.where(df['quality'] > 5, 1, df['quality'] )
df['quality'] = np.where(df['quality'] != 1, 0,  df['quality'])

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        0
# 1      9.8        0
# 2      9.8        0
# ...

# %%
#Total no. of unique values in Target Variable
df['quality'].nunique()
# Out:
# 2

# %%
df['quality'].unique() # we see there is object data in the binary data
# Out:
# array([0, 1], dtype=int64)

# %%
df.shape
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ## From above observations we can see that some columns have 1 and 0 just as we anticipated and we have converted the target variable to binary classification

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# we have again no nulls so we can move on

# %% [markdown]
# Now we can see that the Total Charges column has been converted to float type , Now we can handle the null values

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# # Visualization of the Data

# %%
#Lets see how the data is distributed for every column

import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')


plt.figure(figsize =(20,15), facecolor = 'blue')
plotnumber = 1

for column in df:
    if plotnumber <=12:
        ax = plt.subplot(3,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 20)
        
    plotnumber +=1
plt.tight_layout()

# %%
import seaborn as sns
sns.pairplot(df)

# %% [raw]
# #Outliers Check

# %%
#Lets visualize the data
plt.figure(figsize =(20,25))
graph = 1

for column in df:
    if graph <=12: # as there are 9 columns in data
        plt.subplot(3,4,graph)
        ax=sns.boxplot(data=df[column])
        plt.xlabel(column,fontsize = 15)
        
    graph +=1
plt.show()

# %%
#Lets see how the data is distributed for every column as a whole

#Divide data into features and label

y = df['quality']
X = df.drop(columns=['quality'])

#Visualizing Relationship

plt.figure(figsize =(15,10), facecolor = 'green')
plotnumber = 1

for column in X:
    if plotnumber <=12:
        ax = plt.subplot(3,4,plotnumber)
        plt.scatter(X[column],y)
        plt.xlabel(column,fontsize = 20)
        plt.ylabel('quality',fontsize = 10)
    plotnumber +=1
plt.tight_layout()

# %% [markdown]
# ## USING CORRELATION AND HEAT MAP TO FURTHER STUDY RELATIONSHIP

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor="black",fmt='0.2f')
# Out:
# <Axes: >

# %% [markdown]
# # Correlation of the columns with the target Columns

# %%
df.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.321441
# total sulfur dioxide   -0.231963
# density                -0.159110
# chlorides              -0.109494
# free sulfur dioxide    -0.061757
# pH                     -0.003264
# residual sugar         -0.002160
# fixed acidity           0.095093
# citric acid             0.159129
# sulphates               0.218072
# alcohol                 0.434751
# quality                 1.000000
# Name: quality, dtype: float64

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black",fmt='0.2f')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(22,7))
df.corr()['quality'].sort_values(ascending=False).drop(['quality']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                -0.139303
# dtype: float64

# %% [markdown]
# Keeping +/0.5 as the range for skewness, here are the columns which do not lie within that range
#
# fixed acidity  - nominal
#
# volatile acidity - nominal
#
# residual sugar-nominal
#
# chlorides-nominal
#
# free sulfur dioxide - nominal
#
# sulphates - nominal
#
# alcohol - nominal
#
# Since , we have very few columns and almost 7 columns are have high skewness we will not be able to remove them , as said earlier there are outliers in the data but as the no. of data is very less we will not remove any data and any skewness we will not treat that

# %% [markdown]
# # Considering the outlier removal

# %%
df.shape
# Out:
# (1599, 12)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#           45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#          106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#          151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#          244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#          354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#          467,  480,  480,  494,  515,  544,  554,  554,  555,  555,  557,
#          557,  568,  584,  588,  591,  595,  608,  614,  636,  639,  649,
#          649,  651,  652,  652,  652,  672,  672,  684,  690,  692,  692,
#          695,  723,  724,  730,  754,  776,  777,  795,  821,  836,  837,
#          889,  911,  917,  923,  925,  926,  982, 1017, 1018, 1043, 1051,
#         1051, 1071, 1074, 1079, 1079, 1081, 1081, 1111, 1114, 1131, 1154,
#         1165, 1175, 1186, 1231, 1235, 1244, 1244, 1244, 1260, 1269, 1269,
# ...

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_new_z.shape
# Out:
# (1458, 12)

# %%
##Percentage of data loss:

# %%
Data_loss = ((1599-1458)/1599)*100

# %%
Data_loss
# Out:
# 8.818011257035648

# %% [markdown]
# # Seperating the Columns into Features and Target

# %%
X=df_new_z.drop(['quality'],axis=1)
y=df_new_z['quality']

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1594    0
# 1595    1
# 1596    1
# 1597    0
# 1598    1
# Name: quality, Length: 1458, dtype: int64

# %% [markdown]
# # Scaling the data using Standard Scaler:

# %% [markdown]
# #Training a linear regression model

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Make prediction

# %%
y_pred=model.predict(X_test)

# %%
from sklearn import metrics

# %%
print("Mean Squared error : ",metrics.mean_squared_error(y_test,y_pred))
print("r2_score : ",metrics.r2_score(y_test,y_pred))
# Out:
# Mean Squared error :  0.19288713708479382
# r2_score :  0.21907270387474542

# %% [markdown]
# ##visualizing the prediction from model

# %%
sns.distplot((y_test-y_pred),bins=50)
# Out:
# <Axes: xlabel='quality', ylabel='Density'>

# %%
plt.scatter(y_test,y_pred,marker='o',edgecolors='black',c='blue')
plt.xlabel('Actual Values')
plt.ylabel('Predictions')
plt.title("Scatter plot of actual values and predictions")
# Out:
# Text(0.5, 1.0, 'Scatter plot of actual values and predictions')

# %%
sns.boxplot(y_test-y_pred)
# Out:
# <Axes: >

# %%
print("Predicted wine quality is ",model.predict([[11.2,0.2,0.6,1.9,0.08,17,60,0.9987,3.2,10,1]])[0])
# Out:
# Predicted wine quality is  6.174283277102806
